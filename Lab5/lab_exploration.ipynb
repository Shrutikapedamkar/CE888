# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrutikapedamkar/CE888/blob/main/Lab5/lab_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.datasets import load_wine

from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# * We have loaded the necessary libraries above
# * Now let's load the data

# %%
data = load_wine(as_frame=True)
df = data.data.copy()  # features
# Look at the documentation (https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html)
# and save the label in a column called 'y' in df.
df['y'] = data.target  ## YOUR CODE HERE # label
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  y
# ...

# %%
#How many samples and features are there?

# YOUR CODE HERE
features =data.data.copy()
print('number of samples:', df.shape[0], 'number of features:', features.shape[1])
# Out:
# number of samples: 178 number of features: 13

# %%
# Quiz Q1
# How many instances are there for each class? 

# YOUR CODE HERE
classes =  np.unique(df['y'])
print('Total classes: ',  classes)
print('No. of instances in each class: %s' % np.bincount(df['y']))
# Out:
# Total classes:  [0 1 2]
# No. of instances in each class: [59 71 48]

# %%
# Calculate the means, medians, and standard deviations of each feature
# YOUR CODE HERE
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.alcohol.mean()
# Out:
# 13.000617977528083

# %%
# Plot a boxplot of each feature (NOT THE LABEL!!) (all in one plot -- you can do this with a single line of code).
# Quiz Q2: Is there any feature that is in a clearly different scale than the others?

# YOUR CODE HERE
figure = plt.figure(figsize=(15,20))
for i, col in enumerate(list(features.columns.values)) :
  plt.subplot(4,4,i+1)
  df.boxplot(col)
  plt.grid()
  plt.tight_layout()

# %%
# Let's look at the distributions of values of our features. Draw a histogram for each of the features

# YOUR CODE HERE
plt.hist(features)
plt.show()

# %% [markdown]
# Let's do some multivariate analysis

# %%
# Calculate the correlations between each pair of variables

# YOUR CODE HERE
for col in features.columns.values:
  print("Number of unique values of {} : {}".format(col,str(features[col].nunique())))

sns.catplot(x='nonflavanoid_phenols',data=features,kind='count') 

# Plot a heatmap of the correlations between pairs of FEATURES (i.e., don't include the target!)

# YOUR CODE HERE
plt.figure(figsize=(10,10))
sns.heatmap(features.corr(),color='k',annot=True)
# Out:
# Number of unique values of alcohol : 126
# Number of unique values of malic_acid : 133
# Number of unique values of ash : 79
# Number of unique values of alcalinity_of_ash : 63
# Number of unique values of magnesium : 53
# Number of unique values of total_phenols : 97
# Number of unique values of flavanoids : 132
# Number of unique values of nonflavanoid_phenols : 39
# Number of unique values of proanthocyanins : 101
# Number of unique values of color_intensity : 132
# Number of unique values of hue : 78
# Number of unique values of od280/od315_of_diluted_wines : 122
# Number of unique values of proline : 121

# %%
# What is the highest correlation between features? Ans: total_phenols and flavanoids

# %% [markdown]
# You should have noticed that some of the features are highly correlated.
#
# For this reason, we can run into trouble when trying to train a classifier due to multicolinearity.
#
# Let's do PCA on this dataset to remove these correlations

# %%
# Let's do PCA:
# HINT: I suggest you attempt Q5 of the quiz and then use the function you developed
#       in this and some of the following cells.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, df['y'], test_size=0.25, 
                                                    random_state=10, # always get the same train and test splits
                                                    shuffle=True, stratify=df['y'])
# 1. Standardise your data using a StandardScaler. Make sure you're not scaling the 'y'!

sc = StandardScaler()
X_train_std = sc.fit_transform(features)


# YOUR CODE HERE

# 2. Do PCA with 2 components. How much variance is retained from the original dataset?

# YOUR CODE HERE
scikit_pca = PCA(n_components=2)
X_train_pca = scikit_pca.fit_transform(X_train_std)
print(scikit_pca.explained_variance_ratio_)
# Out:
# [0.36198848 0.1920749 ]

# %%
# Plot your two components, using the label from the data to colour the points

# YOUR CODE HERE
# Out:
# [0.36198848 0.1920749  0.11123631 0.0706903  0.06563294 0.04935823]

# %%
# How many components do you need to keep at least 85% of the variance in the dataset? (Q6)

# YOUR CODE HERE

scikit_pca = PCA(n_components=0.85)
X_train_pca = scikit_pca.fit_transform(X_train_std)
print(scikit_pca.explained_variance_ratio_)
# Out:
# [0.36198848 0.1920749  0.11123631 0.0706903  0.06563294 0.04935823]

# %%
# How much variance is retained if we do PCA with 3 components? (Q7)

# YOUR CODE HERE
scikit_pca = PCA(n_components=3)
X_train_pca = scikit_pca.fit_transform(X_train_std)
print(scikit_pca.explained_variance_ratio_)
# Out:
# [0.36198848 0.1920749  0.11123631]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Let's see how many clusters does K-Means find.

# %%
# Use the elbow method to select the number of clusters in your data using 3 PCs.

# YOUR CODE HERE

# %%
# Now use the silhouette score to choose between the two candidate k values from the previous cell

# YOUR CODE HERE

# %%
# Visualise the first two pcs (using a scatterplot) using the labels from KMeans with your chosen value of k

# YOUR CODE HERE

# %% [markdown]
# Now we can try to understand our clusters.

# %%
# In the original (before PCA and before standardisation) dataframe, add a column called 'cluster' that contains
# the cluster assignment from above

# YOUR CODE HERE

# %%
# Do a boxplot of each feature, separating between clusters

# YOUR CODE HERE

# %% [markdown]
# Write your observations here.
# For example: is there a clear difference between the clusters in terms of alcohol content? What about flavanoids?

# %%
# Feel free to keep playing with the data here!
